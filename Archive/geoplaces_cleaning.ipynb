# %%
# Import Pandas and NumPy
import pandas as pd
import numpy as np

# Import SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# Import Password
from config import password

# %%
conn = (f"postgres:{password}@localhost:5432/restaurant_rating_db")
engine = create_engine(f'postgresql://{conn}')
conn = engine.connect()

# %%
csv_file = "Resources/geoplaces2.csv"
places_df = pd.read_csv(csv_file, encoding="utf-8")
places_df.head()
# Out:
#    placeID   latitude   longitude  \
# 0   134999  18.915421  -99.184871
# 1   132825  22.147392 -100.983092
# 2   135106  22.149709 -100.976093
# 3   132667  23.752697  -99.163359
# 4   132613  23.752903  -99.165076
#
#                                       the_geom_meter  \
# 0  0101000020957F000088568DE356715AC138C0A525FC46...
# 1  0101000020957F00001AD016568C4858C1243261274BA5...
# 2  0101000020957F0000649D6F21634858C119AE9BF528A3...
# 3  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# 4  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
#
#                              name                                 address  \
# 0                 Kiku Cuernavaca                              Revolucion
# 1                 puesto de tacos  esquina santos degollado y leon guzman
# 2      El Rinc�n de San Francisco                         Universidad 169
# 3  little pizza Emilio Portes Gil                 calle emilio portes gil
# 4                   carnitas_mata                  lic. Emilio portes gil
#
#               city            state country fax  ...            alcohol  \
# 0       Cuernavaca          Morelos  Mexico   ?  ...  No_Alcohol_Served
# 1           s.l.p.           s.l.p.  mexico   ?  ...  No_Alcohol_Served
# 2  San Luis Potosi  San Luis Potosi  Mexico   ?  ...          Wine-Beer
# 3        victoria        tamaulipas       ?   ?  ...  No_Alcohol_Served
# 4         victoria       Tamaulipas  Mexico   ?  ...  No_Alcohol_Served
#
#   smoking_area dress_code     accessibility   price                    url  \
# 0         none   informal  no_accessibility  medium  kikucuernavaca.com.mx
# 1         none   informal        completely     low                      ?
# 2  only at bar   informal         partially  medium                      ?
# 3         none   informal        completely     low                      ?
# 4    permitted   informal        completely  medium                      ?
#
#   Rambience franchise    area other_services
# 0  familiar         f  closed           none
# 1  familiar         f    open           none
# 2  familiar         f    open           none
# 3  familiar         t  closed           none
# 4  familiar         t  closed           none
#
# [5 rows x 21 columns]

# %% [markdown]
# Data Cleaning

# %%
places_df.columns
# Out:
# Index(['placeID', 'latitude', 'longitude', 'the_geom_meter', 'name', 'address',
#        'city', 'state', 'country', 'fax', 'zip', 'alcohol', 'smoking_area',
#        'dress_code', 'accessibility', 'price', 'url', 'Rambience', 'franchise',
#        'area', 'other_services'],
#       dtype='object')

# %%
places_df = places_df[["placeID", "latitude", "longitude", "name", "city", "alcohol", "smoking_area",
                      "accessibility", "Rambience"]]
places_df.head()
# Out:
#    placeID   latitude   longitude                            name  \
# 0   134999  18.915421  -99.184871                 Kiku Cuernavaca
# 1   132825  22.147392 -100.983092                 puesto de tacos
# 2   135106  22.149709 -100.976093      El Rinc�n de San Francisco
# 3   132667  23.752697  -99.163359  little pizza Emilio Portes Gil
# 4   132613  23.752903  -99.165076                   carnitas_mata
#
#               city            alcohol smoking_area     accessibility Rambience
# 0       Cuernavaca  No_Alcohol_Served         none  no_accessibility  familiar
# 1           s.l.p.  No_Alcohol_Served         none        completely  familiar
# 2  San Luis Potosi          Wine-Beer  only at bar         partially  familiar
# 3        victoria   No_Alcohol_Served         none        completely  familiar
# 4         victoria  No_Alcohol_Served    permitted        completely  familiar

# %%
places_df = places_df.rename(columns={"Rambience": "ambience"})
places_df = places_df.rename(columns={"placeID": "placeid"})

# %%
places_df[places_df["city"] == "?"]
# Out:
#      placeid   latitude   longitude                                name city  \
# 7     132875  22.149901 -100.993779                           shi ro ie    ?
# 27    132561  23.726819  -99.126506                          cafe ambar    ?
# 31    134975  18.940828  -99.215426                     Rincon del Bife    ?
# 43    132564  23.730925  -99.145185                             churchs    ?
# 45    132925  22.153500 -100.976243                         el pueblito    ?
# 62    132723  22.148934 -101.019845                   Gordas de morales    ?
# 70    132884  22.139578 -101.027886                         dairy queen    ?
# 72    135104  23.752982  -99.168434                                vips    ?
# 83    132717  23.731860  -99.150436                        tortas hawai    ?
# 87    132830  22.150849 -100.939752                     Rincon Huasteco    ?
# 95    132922  22.151135 -100.982311                cafe punta del cielo    ?
# 96    132715  23.732423  -99.158660                tacos de la estacion    ?
# 107   134976  18.916654  -99.227110                             Log Yin    ?
# 110   132921  22.150305 -100.989134                            crudalia    ?
# 111   132594  23.752168  -99.165709  tacos de barbacoa enfrente del Tec    ?
# 118   132584  23.752365  -99.165288                  Gorditas Dona Tota    ?
# 127   135109  18.921785  -99.235350                           Paniroles    ?
# 129   132877  22.135364 -100.934948                    sirloin stockade    ?
#
#                alcohol   smoking_area     accessibility  ambience
# 7            Wine-Beer        section  no_accessibility  familiar
# 27   No_Alcohol_Served           none        completely  familiar
# 31            Full_Bar        section        completely  familiar
# 43   No_Alcohol_Served           none        completely  familiar
# 45           Wine-Beer  not permitted        completely  familiar
# 62            Full_Bar        section        completely  familiar
# 70   No_Alcohol_Served           none        completely  familiar
# 72            Full_Bar  not permitted        completely  familiar
# 83   No_Alcohol_Served  not permitted         partially  familiar
# 87   No_Alcohol_Served           none        completely  familiar
# 95   No_Alcohol_Served      permitted        completely  familiar
# 96   No_Alcohol_Served           none  no_accessibility     quiet
# 107  No_Alcohol_Served           none  no_accessibility  familiar
# 110          Wine-Beer        section        completely     quiet
# 111  No_Alcohol_Served  not permitted        completely  familiar
# 118  No_Alcohol_Served  not permitted        completely  familiar
# 127          Wine-Beer  not permitted  no_accessibility     quiet
# 129  No_Alcohol_Served           none        completely  familiar

# %%
places_df["smoking_area"].unique()
# Out:
# array(['none', 'only at bar', 'permitted', 'section', 'not permitted'],
#       dtype=object)

# %%
places_df = places_df.replace("?", "Not Recorded")

# %%
# check all columns with any missing/null values
places_df.isna().sum()
# Out:
# placeid          0
# latitude         0
# longitude        0
# name             0
# city             0
# alcohol          0
# smoking_area     0
# accessibility    0
# ambience         0
# dtype: int64

# %%
# check all duplicate rows
duplicate_rows_df = places_df[places_df.duplicated()]
print (f"Number of duplicate rows: {duplicate_rows_df.shape}")
# Out:
# Number of duplicate rows: (0, 9)

# %%
# City coulm had lot of variations for "San Luis Potosi"
places_df["city"].unique()
# Out:
# array(['Cuernavaca', 's.l.p.', 'San Luis Potosi', 'victoria ', 'victoria',
#        'Cd Victoria', 'Not Recorded', 'san luis potosi', 'Jiutepec',
#        'cuernavaca', 'slp', 'Soledad', 'san luis potos',
#        'san luis potosi ', 'Ciudad Victoria', 'Cd. Victoria', 's.l.p'],
#       dtype=object)

# %%
# Replace the values 's.l.p.', 'san luis potosi', 'slp', 'san luis potos', 'san luis potosi ' and 's.l.p' 
# with "San Luis Potosi" to get the correct data loaded into Postgres for further analysis
places_df = places_df.replace(['s.l.p.','san luis potosi','slp','san luis potos','san luis potosi ','s.l.p'], "San Luis Potosi")
places_df["city"].unique()
# Out:
# array(['Cuernavaca', 'San Luis Potosi', 'victoria ', 'victoria',
#        'Cd Victoria', 'Not Recorded', 'Jiutepec', 'cuernavaca', 'Soledad',
#        'Ciudad Victoria', 'Cd. Victoria'], dtype=object)

# %%
places_df = places_df.replace('cuernavaca', "Cuernavaca")
places_df = places_df.replace(['victoria ','victoria','Cd Victoria','Cd. Victoria'], 'Ciudad Victoria')
places_df["city"].unique()
# Out:
# array(['Cuernavaca', 'San Luis Potosi', 'Ciudad Victoria', 'Not Recorded',
#        'Jiutepec', 'Soledad'], dtype=object)

# %%
places_df.head(10)
# Out:
#    placeid   latitude   longitude                            name  \
# 0   134999  18.915421  -99.184871                 Kiku Cuernavaca
# 1   132825  22.147392 -100.983092                 puesto de tacos
# 2   135106  22.149709 -100.976093      El Rinc�n de San Francisco
# 3   132667  23.752697  -99.163359  little pizza Emilio Portes Gil
# 4   132613  23.752903  -99.165076                   carnitas_mata
# 5   135040  22.135617 -100.969709        Restaurant los Compadres
# 6   132732  23.754357  -99.171288              Taqueria EL amigo
# 7   132875  22.149901 -100.993779                       shi ro ie
# 8   132609  23.760268  -99.165865        Pollo_Frito_Buenos_Aires
# 9   135082  22.151448 -100.915099            la Estrella de Dimas
#
#               city            alcohol   smoking_area     accessibility  \
# 0       Cuernavaca  No_Alcohol_Served           none  no_accessibility
# 1  San Luis Potosi  No_Alcohol_Served           none        completely
# 2  San Luis Potosi          Wine-Beer    only at bar         partially
# 3  Ciudad Victoria  No_Alcohol_Served           none        completely
# 4  Ciudad Victoria  No_Alcohol_Served      permitted        completely
# 5  San Luis Potosi          Wine-Beer           none  no_accessibility
# 6  Ciudad Victoria  No_Alcohol_Served           none        completely
# 7     Not Recorded          Wine-Beer        section  no_accessibility
# 8  Ciudad Victoria  No_Alcohol_Served  not permitted        completely
# 9  San Luis Potosi  No_Alcohol_Served           none  no_accessibility
#
#    ambience
# 0  familiar
# 1  familiar
# 2  familiar
# 3  familiar
# 4  familiar
# 5  familiar
# 6  familiar
# 7  familiar
# 8     quiet
# 9  familiar

# %% [markdown]
# Database

# %%
# Insert data into Geoplaces table
places_df.to_sql(name='geoplaces', con=engine, if_exists='append', index=False)

# %%
# Query the data in Postgres
geoplaces = pd.read_sql("SELECT * FROM GEOPLACES", conn)
geoplaces.head(10)
# Out:
#    placeid   latitude   longitude                            name  \
# 0   134999  18.915421  -99.184871                 Kiku Cuernavaca
# 1   132825  22.147392 -100.983092                 puesto de tacos
# 2   135106  22.149709 -100.976093      El Rinc�n de San Francisco
# 3   132667  23.752697  -99.163359  little pizza Emilio Portes Gil
# 4   132613  23.752903  -99.165076                   carnitas_mata
# 5   135040  22.135617 -100.969709        Restaurant los Compadres
# 6   132732  23.754357  -99.171288              Taqueria EL amigo
# 7   132875  22.149901 -100.993779                       shi ro ie
# 8   132609  23.760268  -99.165865        Pollo_Frito_Buenos_Aires
# 9   135082  22.151448 -100.915099            la Estrella de Dimas
#
#               city            alcohol   smoking_area     accessibility  \
# 0       Cuernavaca  No_Alcohol_Served           none  no_accessibility
# 1  San Luis Potosi  No_Alcohol_Served           none        completely
# 2  San Luis Potosi          Wine-Beer    only at bar         partially
# 3  Ciudad Victoria  No_Alcohol_Served           none        completely
# 4  Ciudad Victoria  No_Alcohol_Served      permitted        completely
# 5  San Luis Potosi          Wine-Beer           none  no_accessibility
# 6  Ciudad Victoria  No_Alcohol_Served           none        completely
# 7     Not Recorded          Wine-Beer        section  no_accessibility
# 8  Ciudad Victoria  No_Alcohol_Served  not permitted        completely
# 9  San Luis Potosi  No_Alcohol_Served           none  no_accessibility
#
#    ambience
# 0  familiar
# 1  familiar
# 2  familiar
# 3  familiar
# 4  familiar
# 5  familiar
# 6  familiar
# 7  familiar
# 8     quiet
# 9  familiar

# %%
# Import Pandas and NumPy
import pandas as pd
import numpy as np

# Import SQL Alchemy
from sqlalchemy import create_engine
import psycopg2

# Import Password
from config import password

# %%
# userprofile
# Save path to data set in a variable
userprofile = "Resources/userprofile.csv"

# Use Pandas to read data
userprofile_df = pd.read_csv(userprofile, encoding="ISO-8859-1")
userprofile_df.head()
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  color  weight  budget  height
# 0    thrifty-protector      none       student  black      69  medium    1.77
# 1  hunter-ostentatious  Catholic       student    red      40     low    1.87
# 2          hard-worker  Catholic       student   blue      60     low    1.69
# 3          hard-worker      none  professional  green      44  medium    1.53
# 4    thrifty-protector  Catholic       student  black      65  medium    1.69

# %% [markdown]
# Data Cleaning

# %%
# get list of all columns
userprofile_df.columns
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height'],
#       dtype='object')

# %%
# Select specific columns
userprofile_df = userprofile_df[["userID", "latitude", "longitude", "smoker", "drink_level", "ambience", 
                         "transport", "religion"]]
userprofile_df.head()
# Out:
#   userID   latitude   longitude smoker     drink_level ambience transport  \
# 0  U1001  22.139997 -100.978803  false      abstemious   family   on foot
# 1  U1002  22.150087 -100.983325  false      abstemious   family    public
# 2  U1003  22.119847 -100.946527  false  social drinker   family    public
# 3  U1004  18.867000  -99.183000  false      abstemious   family    public
# 4  U1005  22.183477 -100.959891  false      abstemious   family    public
#
#    religion
# 0      none
# 1  Catholic
# 2  Catholic
# 3      none
# 4  Catholic

# %%
# Rename UserID column to userid
userprofile_df = userprofile_df.rename(columns={"userID": "userid"})

# %%
# Replace the values having ? with Nan
userprofile_df = userprofile_df.replace('?', "Not Recorded")
userprofile_df.head()
# Out:
#   userid   latitude   longitude smoker     drink_level ambience transport  \
# 0  U1001  22.139997 -100.978803  false      abstemious   family   on foot
# 1  U1002  22.150087 -100.983325  false      abstemious   family    public
# 2  U1003  22.119847 -100.946527  false  social drinker   family    public
# 3  U1004  18.867000  -99.183000  false      abstemious   family    public
# 4  U1005  22.183477 -100.959891  false      abstemious   family    public
#
#    religion
# 0      none
# 1  Catholic
# 2  Catholic
# 3      none
# 4  Catholic

# %%
# Verify row which had ? and now it got replaced with Nan
userID = userprofile_df.loc[userprofile_df["userid"] == "U1024", :]
userID
# Out:
#    userid   latitude   longitude        smoker drink_level      ambience  \
# 23  U1024  22.154021 -100.976028  Not Recorded  abstemious  Not Recorded
#
#        transport religion
# 23  Not Recorded     none

# %%
# Verify another row which had ? and now it got replaced with Nan
userID = userprofile_df.loc[userprofile_df["userid"] == "U1039", :]
userID
# Out:
#    userid   latitude  longitude smoker     drink_level ambience     transport  \
# 38  U1039  23.738067 -99.139906  false  social drinker  friends  Not Recorded
#
#    religion
# 38     none

# %%
# check all columns with any missing/null values
userprofile_df.isna().sum()
# Out:
# userid         0
# latitude       0
# longitude      0
# smoker         0
# drink_level    0
# ambience       0
# transport      0
# religion       0
# dtype: int64

# %%
# check all duplicate rows
duplicate_rows_df = userprofile_df[userprofile_df.duplicated()]
print (f"Number of duplicate rows: {duplicate_rows_df.shape}")
# Out:
# Number of duplicate rows: (0, 8)

# %% [markdown]
# Database

# %%
# connect to Postgres
engine = create_engine(f"postgresql://postgres:{password}@localhost/restaurant_rating_db")
conn = engine.connect()

# %%
# Insert data into User_Profile table
userprofile_df.to_sql(name='user_profile', con=engine, if_exists='append', index=False)

# %%
# Query the data in Postgres
USER_PROFILE = pd.read_sql("SELECT * FROM USER_PROFILE", conn)
USER_PROFILE.head(10)
# Out:
#   userid   latitude   longitude smoker     drink_level  ambience  transport  \
# 0  U1001  22.139997 -100.978803  false      abstemious    family    on foot
# 1  U1002  22.150087 -100.983325  false      abstemious    family     public
# 2  U1003  22.119847 -100.946527  false  social drinker    family     public
# 3  U1004  18.867000  -99.183000  false      abstemious    family     public
# 4  U1005  22.183477 -100.959891  false      abstemious    family     public
# 5  U1006  22.150000 -100.983000   true  social drinker   friends  car owner
# 6  U1007  22.118464 -100.938256  false  casual drinker  solitary     public
# 7  U1008  22.122989 -100.923811  false  social drinker  solitary     public
# 8  U1009  22.159427 -100.990448  false      abstemious    family    on foot
# 9  U1010  22.190889 -100.998669  false  social drinker   friends  car owner
#
#    religion
# 0      none
# 1  Catholic
# 2  Catholic
# 3      none
# 4  Catholic
# 5      none
# 6  Catholic
# 7  Catholic
# 8  Catholic
# 9      none
